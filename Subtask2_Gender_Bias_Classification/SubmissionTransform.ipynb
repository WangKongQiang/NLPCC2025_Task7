# %%
import csv
import json 

csv_file = './test_submission_distilbert-multi.csv'
json_file = 'test_submission_distilbert-multi.json'

my_json = {}
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        key = row['ori_sentence']
        my_json[key] = row 

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './test_submission_distilbert-multi.csv'
json_file = 'test_submission_distilbert-multi.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)
  

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './test_submission_mbert-uncased--distilbert-multi.csv'
json_file = 'test_submission_mbert-uncased--distilbert-multi.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
            
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './test_submission_mbert-cased--beto-cased--beto-uncased--distilbert-multi.csv'
json_file = 'test_submission_mbert-cased--beto-cased--beto-uncased--distilbert-multi.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './chinese_test_submission_bert-cased--ernie-base--roberta-chinese--roberta-chinese-large.csv'
json_file = 'chinese_test_submission_bert-cased--ernie-base--roberta-chinese--roberta-chinese-large.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './chinese_test_submission_bert-cased--ernie-base--roberta-chinese-large.csv'
json_file = 'chinese_test_submission_bert-cased--ernie-base--roberta-chinese-large.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import csv
import json 

csv_file = './chinese_test_submission_bert-cased.csv'
json_file = 'chinese_test_submission_bert-cased.json'
my_json = []
with open(csv_file, 'r',encoding='utf-8') as fobj:
    reader = csv.DictReader(fobj)
    for row in reader:
        # Use one of the CSV column names as a key
        temp = []
        temp.append(int(row['bias_labels'][1]))
        temp.append(int(row['bias_labels'][4]))
        temp.append(int(row['bias_labels'][7]))
        row['bias_labels']=temp
        my_json.append(row)

with open(json_file,'w') as fobj:
    fobj.write(json.dumps(my_json, indent=2))

# %%
import pandas as pd
df = pd.read_csv('./test_submission_distilbert-multi.csv').head()
result = df.to_json(indent=4, orient='records', lines=True)
print(result)
# Out:
#     {
#         "ori_sentence":"\u970d\u5c0a\u79f0\u81ea\u5df1\u662f\u201c\u6781\u7aef\u4e3b\u4e49\u201d\uff0c\u8ba4\u4e3a\u5973\u4eba\u5c31\u8be5\u6709\u5973\u4eba\u7684\u6837\u5b50\uff0c\u4e0d\u7136\u201c\u4f1a\u628a\u5979\u6253\u6b7b\u201d\uff0c\u5e76\u79f0\u201c\u6211\u65ad\u5b9a\u6211\u80af\u5b9a\u4f1a\u51fa\u8f68\u201d\uff0c\u201c\u6211\u4e00\u76f4\u5e0c\u671b\u9732\u9732\u63d0\u5206\u624b\uff0c\u4f46\u5979\u4e0d\u53ef\u80fd\uff0c\u6211\u5bf9\u9732\u9732\u6ca1\u6709\u8fc7\u70ed\u604b\u7684\u201d\u3002",
#         "bias_labels":"[0, 0, 1]"
#     }
#
#     {
#         "ori_sentence":"\u6587\u6848\u804c\u4f4d\u4ec5\u62db\u7537\u6027\uff0c\u56e0\u4e3a\u9700\u8981\u51fa\u5dee\u3002",
#         "bias_labels":"[0, 0, 0]"
#     }
#
#     {
#         "ori_sentence":"\u597d\u50cf\u6240\u6709\u5973\u4eba\u5728\u5de5\u4f5c\u4e4b\u524d\u90fd\u5f97\u53d8\u7f8e\uff0c\u4e00\u4e2a\u5973\u4eba\u6253\u626e\u662f\u80a4\u6d45\uff0c\u800c\u4e0d\u6253\u626e\u662f\u6ca1\u793c\u8c8c\u3002",
# ...

# %%
import json

f=open("./test_submission_distilbert-multi.csv","r",encoding='utf-8')
ls=[]
for line in f:
        line = line.replace("\n", "")
        ls.append(line.split(","))
print(ls)
for i in range(1,len(ls)):
    ls[i]=dict(zip(ls[0],ls[i]))
# Out:
# [['ori_sentence', 'bias_labels'], ['霍尊称自己是“极端主义”，认为女人就该有女人的样子，不然“会把她打死”，并称“我断定我肯定会出轨”，“我一直希望露露提分手，但她不可能，我对露露没有过热恋的”。', '"[0', ' 0', ' 1]"'], ['文案职位仅招男性，因为需要出差。', '"[0', ' 0', ' 0]"'], ['好像所有女人在工作之前都得变美，一个女人打扮是肤浅，而不打扮是没礼貌。', '"[1', ' 0', ' 0]"'], ['如果第一个登上月球的是女性，她可能也要穿高跟鞋。', '"[0', ' 0', ' 0]"'], ['受传统观念和生理条件影响，育儿和承担家庭责任被视为女性天职。', '"[0', ' 0', ' 0]"'], ['授课人莫兰说，大自然给了男性接受外部挑战的理想条件，所以男人要在社会、家庭生活中担任好“领导”角色，学会与女性成员相处，主动将自己视为前进者，开拓者。', '"[1', ' 0', ' 0]"'], ['中国女人挑选男人的标准是男人要会赚钱，至于良心好不好不管，所以中国女性的堕落导致了国家的堕落。', '"[1', ' 0', ' 0]"'], ['一开学术会议，男博士们都在研究课题，女博士则聊多大生小孩，痛诉“血泪史”。', '"[0', ' 0', ' 0]"'], ['比起男人和男孩之间的轻易合作，女性之间更容易在社交场合出现相互排挤的现象。', '"[0', ' 0', ' 0]"'], ['戏剧故事中，女性过了30岁就开始不为自己而活，或是围绕儿女做个讨人嫌的母亲（这样还能有点存在感），或是彻底沦为故事的背景板。', '"[0', ' 0', ' 0]"'], ['男性都期望女性是温暖的“家庭照料者”，女性则更青睐拥有社会地位与资源的男性。', '"[1', ' 0', ' 0]"'], ['我现在的梦想就是和妈妈一样，做一个家庭主妇，我感觉女人就要像一个家庭主妇。', '"[1', ' 0', ' 0]"'], ['女性应该学习文科而不是理科，女性不适合科学研究。', '"[0', ' 0', ' 0]"'], ['看看文马恋爱时的那组写真，马伊琍或是向内靠近挽住文章的胳膊，或是文章将手臂搭在马伊琍肩膀上，很有大女人和小男人的强弱差异。', '"[0'
# ...

# %%
import json

f=open("./test_submission_distilbert-multi.csv","r",encoding='utf-8')
ls=[]
for line in f:
        line = line.replace("\n", "").replace("\"", "-")
        ls.append(line.split(",-"))

f.close()
fw=open("test_submission_distilbert-multi.json","w",encoding='utf-8')
for i in range(1,len(ls)):
    ls[i]=dict(zip(ls[0],ls[i]))
a = json.dumps(ls[1:],sort_keys=True,indent=4,ensure_ascii=False)
print(a)
fw.write(a)
fw.close()
# Out:
# [
#     {
#         "ori_sentence,bias_labels": "霍尊称自己是“极端主义”，认为女人就该有女人的样子，不然“会把她打死”，并称“我断定我肯定会出轨”，“我一直希望露露提分手，但她不可能，我对露露没有过热恋的”。"
#     },
#     {
#         "ori_sentence,bias_labels": "文案职位仅招男性，因为需要出差。"
#     },
#     {
#         "ori_sentence,bias_labels": "好像所有女人在工作之前都得变美，一个女人打扮是肤浅，而不打扮是没礼貌。"
#     },
#     {
#         "ori_sentence,bias_labels": "如果第一个登上月球的是女性，她可能也要穿高跟鞋。"
#     },
#     {
#         "ori_sentence,bias_labels": "受传统观念和生理条件影响，育儿和承担家庭责任被视为女性天职。"
#     },
#     {
#         "ori_sentence,bias_labels": "授课人莫兰说，大自然给了男性接受外部挑战的理想条件，所以男人要在社会、家庭生活中担任好“领导”角色，学会与女性成员相处，主动将自己视为前进者，开拓者。"
#     },
#     {
#         "ori_sentence,bias_labels": "中国女人挑选男人的标准是男人要会赚钱，至于良心好不好不管，所以中国女性的堕落导致了国家的堕落。"
#     },
#     {
#         "ori_sentence,bias_labels": "一开学术会议，男博士们都在研究课题，女博士则聊多大生小孩，痛诉“血泪史”。"
#     },
#     {
#         "ori_sentence,bias_labels": "比起男人和男孩之间的轻易合作，女性之间更容易在社交场合出现相互排挤的现象。"
#     },
#     {
# ...

# %%
import json

f=open("./task1/data/test_submit_bagging.csv","r",encoding='utf-8')
ls=[]
for line in f:
        line = line.replace("\n", "")
        ls.append(line.split(","))

f.close()
fw=open("test_submit_bagging.json","w",encoding='utf-8')
for i in range(1,len(ls)):
    ls[i]=dict(zip(ls[0],ls[i]))
a = json.dumps(ls[1:],sort_keys=True,indent=4,ensure_ascii=False)
print(a)
fw.write(a)
fw.close()
# Out:
# [
#     {
#         "is_biased": "False",
#         "text": "在德国，女性的平均收入在今天依然比男性低18%。"
#     },
#     {
#         "is_biased": "False",
#         "text": "中年男性要说真正最大的玩具，应该说核心还是在于搞钱，只要是可以搞钱的事情，中年男性就会瞬间上头，就像年轻女性动不动瞬间狂喊男人下头一样。"
#     },
#     {
#         "is_biased": "False",
#         "text": "赛场上，我们凝神聚力，伴随着欢快的音乐，踏着节拍、变换队形，以灵动舞步展现自信舞姿，彰显当代女警的活力风采。"
#     },
#     {
#         "is_biased": "False",
#         "text": "由男性带大的孩子智商高，他们在学校里的成绩往往更好，将来走向社会也更容易成功。"
#     },
#     {
#         "is_biased": "False",
#         "text": "在舆论场上，酒吧里出现的女性，其受到的规训压力，也远大于同时出现在酒吧的男性。"
#     },
#     {
#         "is_biased": "False",
#         "text": "什么事都听他的，我就跟在他后面做一个小女人就行了。"
#     },
#     {
#         "is_biased": "False",
#         "text": "5000多人的管制队伍中，女性并不鲜见，高强度脑力运算，颠倒生物钟，瞬时决断力，这种长时间的工作压力对于男性来说尚难完全适应，但女管制员却利用自己亲和的通话、细腻的指挥、和谐的配合，活跃于这支战斗集体中。"
#     },
#     {
#         "is_biased": "False",
#         "text": "他认为，虽然很多男性表示愿意促成男女平等，反对性别偏见，但他们并不愿意真正为此付出实际行动。"
#     },
#     {
# ...

# %%
import json

f=open("./task1/data/test_submit_bagging_1.csv","r",encoding='utf-8')
ls=[]
for line in f:
        line = line.replace("\n", "")
        ls.append(line.split(","))

f.close()
fw=open("test_submit_bagging_1.json","w",encoding='utf-8')
for i in range(1,len(ls)):
    ls[i]=dict(zip(ls[0],ls[i]))
a = json.dumps(ls[1:],sort_keys=True,indent=4,ensure_ascii=False)
print(a)
fw.write(a)
fw.close()
# Out:
# [
#     {
#         "is_biased": "False",
#         "text": "在德国，女性的平均收入在今天依然比男性低18%。"
#     },
#     {
#         "is_biased": "False",
#         "text": "中年男性要说真正最大的玩具，应该说核心还是在于搞钱，只要是可以搞钱的事情，中年男性就会瞬间上头，就像年轻女性动不动瞬间狂喊男人下头一样。"
#     },
#     {
#         "is_biased": "True",
#         "text": "赛场上，我们凝神聚力，伴随着欢快的音乐，踏着节拍、变换队形，以灵动舞步展现自信舞姿，彰显当代女警的活力风采。"
#     },
#     {
#         "is_biased": "False",
#         "text": "由男性带大的孩子智商高，他们在学校里的成绩往往更好，将来走向社会也更容易成功。"
#     },
#     {
#         "is_biased": "True",
#         "text": "在舆论场上，酒吧里出现的女性，其受到的规训压力，也远大于同时出现在酒吧的男性。"
#     },
#     {
#         "is_biased": "False",
#         "text": "什么事都听他的，我就跟在他后面做一个小女人就行了。"
#     },
#     {
#         "is_biased": "True",
#         "text": "5000多人的管制队伍中，女性并不鲜见，高强度脑力运算，颠倒生物钟，瞬时决断力，这种长时间的工作压力对于男性来说尚难完全适应，但女管制员却利用自己亲和的通话、细腻的指挥、和谐的配合，活跃于这支战斗集体中。"
#     },
#     {
#         "is_biased": "True",
#         "text": "他认为，虽然很多男性表示愿意促成男女平等，反对性别偏见，但他们并不愿意真正为此付出实际行动。"
#     },
#     {
#         "is_biased": "False",
# ...
